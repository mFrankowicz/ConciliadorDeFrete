# %%
from conciliador import *

# %%
pedidos_df = pedidos("2023-06-01")
# Out:
# atualizando pedidos a partir de: 2023-06-01T03:00:00.000Z
# numero de pedidos para atualizar: 154
# coletando pedidos: 0/15400
# coletando pedidos: 100/15400
# coletando pedidos: 200/15400
# coletando pedidos: 300/15400
# coletando pedidos: 400/15400
# coletando pedidos: 500/15400
# coletando pedidos: 600/15400
# coletando pedidos: 700/15400
# coletando pedidos: 800/15400
# coletando pedidos: 900/15400
# coletando pedidos: 1000/15400
# coletando pedidos: 1100/15400
# coletando pedidos: 1200/15400
# coletando pedidos: 1300/15400
# coletando pedidos: 1400/15400
# coletando pedidos: 1500/15400
# coletando pedidos: 1600/15400
# coletando pedidos: 1700/15400
# coletando pedidos: 1800/15400
# coletando pedidos: 1900/15400
# coletando pedidos: 2000/15400
# coletando pedidos: 2100/15400
# coletando pedidos: 2200/15400
# coletando pedidos: 2300/15400
# coletando pedidos: 2400/15400
# coletando pedidos: 2500/15400
# coletando pedidos: 2600/15400
# coletando pedidos: 2700/15400
# ...

# %%
prefaturas_df = gerar_prefatura("2023-06-01", "2023-09-21")
# Out:
# <Response [200]>
# TOKEN---------------- eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiJ9.eyJzdWIiOiJnYWJyaWVsLmx1Y2luYUBjYXJvbGluYWJhYnkuY29tLmJyIiwiY2xpZW50SWQiOjQzNzU5LCJwcm9maWxlIjpbXSwiaXNBZG1pbiI6ZmFsc2UsImV4cCI6MTY5NTMwOTE5NiwiaWF0IjoxNjk1MzA1NTk2LCJzYW5kYm94Q2xpZW50SWQiOjQzNzU4fQ.2GdaE7Ulg5qQbDwW0r4Hj4ipuFaKt0RXLaYwRAWjrbendZnRCLDT3bxyTi13QCFakkClcJ_DoKj_juuBhNIcvg
# conciliacoes response:  <Response [200]>
# retorno api, tamanho:  11982

# %%
# transportadoras_df = carregar_tabela_padrao("PAJUCARA")
jamef_df = carregar_tabela_jamef("JAMEF")
moovelog_df = carregar_tabela_moovelog("MOOVELOG")
dominalog_df = carregar_tabela_padrao("DOMINALOG")
nova_era_df = carregar_tabela_padrao("NOVA ERA")
pajucara_df = carregar_tabela_padrao("PAJUCARA")
stl_df = carregar_tabela_padrao("STL")
transbarbosa_df = carregar_tabela_padrao("TRANSBARBOSA")
vhz_df = carregar_tabela_padrao("VHZ")

# %%
# tabelas_unidas = unir_tabelas(prefaturas_df, pedidos_df, transportadoras_df, 30)
jamef_unidas = unir_tabelas(prefaturas_df, pedidos_df, jamef_df, 23)
moovelog_unidas = unir_tabelas(prefaturas_df, pedidos_df, moovelog_df, 7524)
dominalog_unidas = unir_tabelas(prefaturas_df, pedidos_df, moovelog_df, 196)
nova_era_unidas = unir_tabelas(prefaturas_df, pedidos_df, moovelog_df, 17387)
pajucara_unidas = unir_tabelas(prefaturas_df, pedidos_df, moovelog_df, 30)
stl_unidas = unir_tabelas(prefaturas_df, pedidos_df, moovelog_df, 1297)
transbarbosa_unidas = unir_tabelas(prefaturas_df, pedidos_df, moovelog_df, 17681)
vhz_unidas = unir_tabelas(prefaturas_df, pedidos_df, moovelog_df, 14567)

# %%
conciliacao_jamef = conciliar(jamef_unidas)
conciliacao_moovelog = conciliar(moovelog_unidas)
conciliacao_dominalog = conciliar(dominalog_unidas)
conciliacao_nova_era = conciliar(nova_era_unidas)
conciliacao_pajucara = conciliar(pajucara_unidas)
conciliacao_stl = conciliar(stl_unidas)
conciliacao_transbarbosa = conciliar(transbarbosa_unidas)
conciliacao_vhz = conciliar(vhz_unidas)

# %%
salvar_conciliacao(conciliacao_jamef, "conciliadas")
salvar_conciliacao(conciliacao_moovelog, "conciliadas")
salvar_conciliacao(conciliacao_dominalog, "conciliadas")
salvar_conciliacao(conciliacao_nova_era, "conciliadas")
salvar_conciliacao(conciliacao_pajucara, "conciliadas")
salvar_conciliacao(conciliacao_stl, "conciliadas")
salvar_conciliacao(conciliacao_transbarbosa, "conciliadas")
salvar_conciliacao(conciliacao_vhz, "conciliadas")
